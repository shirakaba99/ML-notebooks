# %% [markdown]
# # sklearnを使ってk-meansを試してみる

# %% [markdown]
# ## データの読み込みと可視化
#
# seabornという可視化ライブラリからiris dataを読み込んで可視化までしてみます。

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris") 

# ちなみにこのirisはpandasのdataframeです。

# %%
sns.pairplot(iris, hue = "species", diag_kind="kde")

# %% [markdown]
# ## sklearn.cluster.KMeansを使ってクラスタリング
#
# sklearnのKmeansでクラスタリングを行います。
#
# ここで、KMeansの引数は
# - n_clusters: クラスタの数
# - max_iter: 学習のループ回数
# - inin: 平均の初期値の決め方
# - n_jobs: k-meansを何並列にするか(-1ならばpcのコア数分だけ並列してくれます）

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3, max_iter=30, init="random", n_jobs=-1)

# %%
cluster = kmeans.fit_predict(iris.values[:,0:4])

# %%
iris2 = iris.iloc[:,[0,1,2,3]]
iris2["cluster"] = ["cluster"+str(x) for x in cluster]

iris2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width   cluster
# 0             5.1          3.5           1.4          0.2  cluster0
# 1             4.9          3.0           1.4          0.2  cluster0
# 2             4.7          3.2           1.3          0.2  cluster0
# 3             4.6          3.1           1.5          0.2  cluster0
# 4             5.0          3.6           1.4          0.2  cluster0
# 5             5.4          3.9           1.7          0.4  cluster0
# 6             4.6          3.4           1.4          0.3  cluster0
# 7             5.0          3.4           1.5          0.2  cluster0
# 8             4.4          2.9           1.4          0.2  cluster0
# 9             4.9          3.1           1.5          0.1  cluster0
# 10            5.4          3.7           1.5          0.2  cluster0
# 11            4.8          3.4           1.6          0.2  cluster0
# 12            4.8          3.0           1.4          0.1  cluster0
# 13            4.3          3.0           1.1          0.1  cluster0
# 14            5.8          4.0           1.2          0.2  cluster0
# 15            5.7          4.4           1.5          0.4  cluster0
# 16            5.4          3.9           1.3          0.4  cluster0
# 17            5.1          3.5           1.4          0.3  cluster0
# 18            5.7          3.8           1.7          0.3  cluster0
# 19            5.1          3.8           1.5          0.3  cluster0
# 20            5.4          3.4           1.7          0.2  cluster0
# 21            5.1          3.7           1.5          0.4  cluster0
# 22            4.6          3.6           1.0          0.2  cluster0
# 23            5.1          3.3           1.7          0.5  cluster0
# 24            4.8          3.4           1.9          0.2  cluster0
# 25            5.0          3.0           1.6          0.2  cluster0
# 26            5.0          3.4           1.6          0.4  cluster0
# 27            5.2          3.5           1.5          0.2  cluster0
# 28            5.2          3.4           1.4          0.2  cluster0
# 29            4.7          3.2           1.6          0.2  cluster0
# ..            ...          ...           ...          ...       ...
# 120           6.9          3.2           5.7          2.3  cluster2
# 121           5.6          2.8           4.9          2.0  cluster1
# 122           7.7          2.8           6.7          2.0  cluster2
# 123           6.3          2.7           4.9          1.8  cluster1
# 124           6.7          3.3           5.7          2.1  cluster2
# 125           7.2          3.2           6.0          1.8  cluster2
# 126           6.2          2.8           4.8          1.8  cluster1
# 127           6.1          3.0           4.9          1.8  cluster1
# 128           6.4          2.8           5.6          2.1  cluster2
# 129           7.2          3.0           5.8          1.6  cluster2
# 130           7.4          2.8           6.1          1.9  cluster2
# 131           7.9          3.8           6.4          2.0  cluster2
# 132           6.4          2.8           5.6          2.2  cluster2
# 133           6.3          2.8           5.1          1.5  cluster1
# 134           6.1          2.6           5.6          1.4  cluster2
# 135           7.7          3.0           6.1          2.3  cluster2
# 136           6.3          3.4           5.6          2.4  cluster2
# 137           6.4          3.1           5.5          1.8  cluster2
# 138           6.0          3.0           4.8          1.8  cluster1
# 139           6.9          3.1           5.4          2.1  cluster2
# 140           6.7          3.1           5.6          2.4  cluster2
# 141           6.9          3.1           5.1          2.3  cluster2
# 142           5.8          2.7           5.1          1.9  cluster1
# 143           6.8          3.2           5.9          2.3  cluster2
# 144           6.7          3.3           5.7          2.5  cluster2
# 145           6.7          3.0           5.2          2.3  cluster2
# 146           6.3          2.5           5.0          1.9  cluster1
# 147           6.5          3.0           5.2          2.0  cluster2
# 148           6.2          3.4           5.4          2.3  cluster2
# 149           5.9          3.0           5.1          1.8  cluster1
#
# [150 rows x 5 columns]

# %% [markdown]
# ## クラスタリング結果の可視化
#
# 最初の同じグラフを作って比較してみましょう。

# %%
sns.pairplot(iris2, hue = "cluster", diag_kind="kde")
