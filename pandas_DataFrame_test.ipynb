# %%
import pandas as pd
import numpy as np
from sklearn import datasets
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris.data)
df["label"] = [iris.target_names[i] for i in iris.target]
df.head()
# Out:
#      0    1    2    3   label
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
df.tail()
# Out:
#        0    1    2    3      label
# 145  6.7  3.0  5.2  2.3  virginica
# 146  6.3  2.5  5.0  1.9  virginica
# 147  6.5  3.0  5.2  2.0  virginica
# 148  6.2  3.4  5.4  2.3  virginica
# 149  5.9  3.0  5.1  1.8  virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# 0        float64
# 1        float64
# 2        float64
# 3        float64
# label     object
# dtype: object

# %%
df.describe()
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df[:20].plot(kind="bar", subplots=True, figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001BD46070FD0>,
# ...
#       dtype=object)

# %%
sns.pairplot(df, hue="label")

# %%
df.sort_values(0).head()
# Out:
#       0    1    2    3   label
# 13  4.3  3.0  1.1  0.1  setosa
# 42  4.4  3.2  1.3  0.2  setosa
# 38  4.4  3.0  1.3  0.2  setosa
# 8   4.4  2.9  1.4  0.2  setosa
# 41  4.5  2.3  1.3  0.3  setosa

# %%
df[0:5] # スライス
# Out:
#      0    1    2    3   label
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
df.iloc[:5,:-1] # numpy.arrayのようなスライスもできる
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
df.iloc[2,3]
# Out:
# 0.2

# %%
df2 = df.iloc[:,:-1].apply(stats.zscore, axis=0) 
df.head()
# Out:
#      0    1    2    3   label
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
df2[:20].plot(kind="bar", subplots=True, figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001BD46539390>,
# ...
#       dtype=object)

# %%
sc = StandardScaler()
sc.fit_transform(df.iloc[:,:-1])
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...
